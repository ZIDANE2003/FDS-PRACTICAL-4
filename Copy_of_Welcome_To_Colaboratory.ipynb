# %% [markdown]
# <a href="https://colab.research.google.com/github/ZIDANE2003/FDS-PRACTICAL-4/blob/main/Copy_of_Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  
''' Python Program for 
 Addition of two matrices 
Subtraction of two matrices 
 Multiplication of two matrices 
 Transpose of a matrix '''



m= int(input("enter number of rows: "))
n = int(input("enter number of columns: "))
A = [[0 for col in range(n)] for row in range(m)]
for i in range(m):
    for j in range(n):
        num = int(input("Enter the elements in first matrix: "))
        A[i][j]= num

print("The first matrix is:")
print(A)

B = [[0 for col in range(n)] for row in range(m)]
for i in range(m):
    for j in range(n):
        num = int(input("Enter the elements in second matrix: "))
        B[i][j]= num

print("The second matrix is...")
print(B)
# addition of two matrices
def add_matrix(A,B):
    result = [[A[i][j] + B[i][j]  for j in range(len(A[0]))] for i in range(len(A))]

    print("The Addition of Two Matrices:")
    for r in result:  
        print(r)
 
#subtraction of two matrices
def sub_matrix(A,B):
    result = [[A[i][j] - B[i][j]  for j in range(len(A[0]))] for i in range(len(A))]

    print("The Subtraction of Two Matrices...")
    for r in result:
        print(r)

#Multiplication of two matrices
def Mul_matrix(A,B):
    result = [[0 for col in range(n)] for row in range(m)]
    for i in range(len(A)):  
       for j in range(len(B[0])):  
           for k in range(len(B)):  
               result[i][j] += A[i][k] * B[k][j]  

    print("Matrix Multiplication is: ")
    for r in result:  
        print(r) 
 #Transpose 
def transpose():
    result = [[0 for col in range(n)] for row in range(m)]
    
    for i in range(len(A)):  
       for j in range(len(A[0])):  
           result[j][i] = A[i][j]  
    print("Transpose of First Matrix is:")
    for r in result:  
        print(r)  
    for i in range(len(B)):  
       for j in range(len(B[0])):  
           result[j][i] = B[i][j]  
  
    print("Transpose of Second  Matrix is:")
    for r in result:  
        print(r)  

add_matrix(A,B)  
sub_matrix(A,B)
transpose() 
Mul_matrix(A,B)
# Out:
# enter number of rows: 3
# enter number of columns: 3
# Enter the elements in first matrix: 1
# Enter the elements in first matrix: 2
# Enter the elements in first matrix: 3
# Enter the elements in first matrix: 4
# Enter the elements in first matrix: 5
# Enter the elements in first matrix: 6
# Enter the elements in first matrix: 7
# Enter the elements in first matrix: 8
# Enter the elements in first matrix: 9
# The first matrix is:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# Enter the elements in second matrix: 9
# Enter the elements in second matrix: 8
# Enter the elements in second matrix: 7
# Enter the elements in second matrix: 6
# Enter the elements in second matrix: 5
# Enter the elements in second matrix: 4
# Enter the elements in second matrix: 3
# Enter the elements in second matrix: 2
# Enter the elements in second matrix: 1
# The second matrix is...
# [[9, 8, 7], [6, 5, 4], [3, 2, 1]]
# The Addition of Two Matrices:
# [10, 10, 10]
# [10, 10, 10]
# [10, 10, 10]
# The Subtraction of Two Matrices...
# [-8, -6, -4]
# [-2, 0, 2]
# [4, 6, 8]
# Transpose of First Matrix is:
# [1, 4, 7]
# [2, 5, 8]
# [3, 6, 9]
# Transpose of Second  Matrix is:
# [9, 6, 3]
# [8, 5, 2]
# [7, 4, 1]
# Matrix Multiplication is:
# [30, 24, 18]
# [84, 69, 54]
# [138, 114, 90]
